# %% [markdown]
# <a href="https://colab.research.google.com/github/rajmishra-dev/python-project/blob/main/AllPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OOPs concept in python
# 1. Inheritance:
#     Inheritance is a fundamental concept in OOPs that allows a class to inherit attributes and methods from another class.

# %%
class A():
  a = " Hello, I am Apple!"

  def a(self):
    print(self.a)

class B():
  b = "Hello, I am Boll!"

  def b(self):
    print(self.b)

class C(A,B):

  c = " Hello, I am Cute!"

  def c(self):
    print(self.c)


# Instantiate objects and call methods after class definitions
objA = A()
objB = B()
objC = C()

objA.a()
objB.b()
objC.c()
# Out:
# <bound method A.a of <__main__.A object at 0x7bfd9cf9ec90>>
# <bound method B.b of <__main__.B object at 0x7bfd9cf9e840>>
# <bound method C.c of <__main__.C object at 0x7bfd9cf9fda0>>

# %% [markdown]
# # The __init__() Method
# All classes have a built-in method called __init__(), which is always executed when the class is being initiated.
#
# The __init__() method is used to assign values to object properties, or to perform operations that are necessary when the object is being created.

# %%
class student:
  name = "RAj"
  def __init__(Self):
    print(Self.name)
obj = student()
# Out:
# RAj
