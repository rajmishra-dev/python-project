# %% [markdown]
# <a href="https://colab.research.google.com/github/rajmishra-dev/python-project/blob/main/ML_PY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basic Pandas Fundtion

# %%
import pandas as pd
d = {"name" : ["navdeep","ram","ravi"],
     "class": ["bsc","msc","btech"],
     "roll no. ": ["1","2","3"]}
a = pd.DataFrame(d)
print(a)

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-0c4fde95-76e4-474d-a944-1c860fbfecc0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0c4fde95-76e4-474d-a944-1c860fbfecc0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("/content/student_dataset_0_to_49.csv")

print(df)
# Out:
#     No     Id            Name  Age      City  Marks
# 0    0  ST001    Rahul Sharma   20    Bhopal     85
# 1    1  ST002     Priya Verma   21    Indore     92
# 2    2  ST003      Amit Patel   19    Ujjain     78
# 3    3  ST004      Neha Singh   20   Gwalior     88
# 4    4  ST005    Rohit Mishra   22    Bhopal     74
# 5    5  ST006    Anjali Gupta   21    Indore     95
# 6    6  ST007     Vikas Yadav   20  Jabalpur     81
# 7    7  ST008    Pooja Sharma   19    Bhopal     89
# 8    8  ST009      Arjun Jain   22     Sagar     76
# 9    9  ST010     Simran Khan   20    Indore     91
# 10  10  ST011     Karan Verma   21    Ujjain     83
# 11  11  ST012     Meena Patel   19   Gwalior     87
# 12  12  ST013     Akash Singh   20    Bhopal     72
# 13  13  ST014      Riya Gupta   21  Jabalpur     94
# 14  14  ST015    Manish Yadav   22    Indore     79
# 15  15  ST016      Sneha Jain   20     Sagar     86
# 16  16  ST017   Deepak Sharma   19    Bhopal     68
# ...

# %% [markdown]
# DATA

# %%
print(df.loc[0])
# Out:
# No                  0
# Id              ST001
# Name     Rahul Sharma
# Age                20
# City           Bhopal
# Marks              85
# Name: 0, dtype: object

# %%
print(df.iloc[1])
# Out:
# No                 1
# Id             ST002
# Name     Priya Verma
# Age               21
# City          Indore
# Marks             92
# Name: 1, dtype: object

# %%
df[df["City"] == "Bhopal"]
# Out:
#     No     Id           Name  Age    City  Marks
# 0    0  ST001   Rahul Sharma   20  Bhopal     85
# 4    4  ST005   Rohit Mishra   22  Bhopal     74
# 7    7  ST008   Pooja Sharma   19  Bhopal     89
# 12  12  ST013    Akash Singh   20  Bhopal     72
# 16  16  ST017  Deepak Sharma   19  Bhopal     68
# 20  20  ST021   Sachin Gupta   21  Bhopal     84
# 24  24  ST025   Varun Sharma   22  Bhopal     80
# 29  29  ST030    Ayesha Khan   22  Bhopal     97
# 33  33  ST034     Isha Gupta   20  Bhopal     87
# 37  37  ST038  Ritika Sharma   19  Bhopal     93
# 41  41  ST042   Monika Verma   21  Bhopal     89
# 47  47  ST048    Sonam Gupta   19  Bhopal     92

# %%
print(df[(df["Marks"] > 80) & (df["Age"] < 25)])
# Out:
#     No     Id            Name  Age      City  Marks
# 0    0  ST001    Rahul Sharma   20    Bhopal     85
# 1    1  ST002     Priya Verma   21    Indore     92
# 3    3  ST004      Neha Singh   20   Gwalior     88
# 5    5  ST006    Anjali Gupta   21    Indore     95
# 6    6  ST007     Vikas Yadav   20  Jabalpur     81
# 7    7  ST008    Pooja Sharma   19    Bhopal     89
# 9    9  ST010     Simran Khan   20    Indore     91
# 10  10  ST011     Karan Verma   21    Ujjain     83
# 11  11  ST012     Meena Patel   19   Gwalior     87
# 13  13  ST014      Riya Gupta   21  Jabalpur     94
# 15  15  ST016      Sneha Jain   20     Sagar     86
# 17  17  ST018     Kavya Verma   21    Ujjain     90
# 19  19  ST020     Nisha Singh   22   Gwalior     93
# 20  20  ST021    Sachin Gupta   21    Bhopal     84
# 21  21  ST022     Komal Yadav   19  Jabalpur     88
# 23  23  ST024      Tanya Khan   21    Indore     96
# 25  25  ST026     Divya Verma   20    Ujjain     85
# ...
